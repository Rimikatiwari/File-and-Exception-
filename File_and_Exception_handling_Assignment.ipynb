# %% [markdown]
# 1. What is the difference between interpreted and compiled languages ?
#
# --> the diference between iterpreted and compliled languages lies in how they are executed by the computer. interpreted languages priotize flexiblity and ease of use and compiled languages emphasize performance and efficiency.
#
# 2. What is exception handling in Python?
#
# --> exception handling in python is a mechanism that allows you to manage errors that occurs during the excution of program without even crashing it. it prevents program crashing, helps maintain program flow.
#
# 3. What is the purpose of the finally block in exception handling?
#
# -->  it used to execute code that should run no matter what happens. its primary purpose is to ensure cleanup or finalisation actions. such as closing files, releasing resources or cleanup variables. the finally block ensurs that crictical cleanup are always performed.
#
# 4. What is logging in Python?
#
# --> loggng in python is the process of tracking events or messeges that occurs during the execution of a program. it provides a way to output status information, warnings, errors, or debugging details. it offers a flexible and standized way to log messeges of varing sverl levels. it hels creating robust, maintainable appicatins.
#
# 5. What is the significance of the __del__ method in Python?
#
# --> the del method is a special method called a destructor. it automatically nvoked when an object is about to be destroyed, typically when it goes out of spope or its reference count drops to zero. the__del__ method is usefule for cleanup tasks when an object is about to be destroyed.
#
# 6. What is the difference between import and from ... import in Python?
#
# -->both are used to bring external modules or specific components of a module into your code. import statement is used to import entire module into your program. and the from import statement is used to import specific attributes from a module. you can acces them directly without the module name no like the other one where you have to put the module name.
#
# 7. How can you handle multiple exceptions in Python?
#
# --> you can handle multipe exceptions using several approaches. this allows you to handle different types of errors beautifully and respond accordingly. 1. using multiple exept blocks. 2.handling multiple exceptions in a single except block. 3.using else with try-except. 4.using a generic exception.
#
# 8. What is the purpose of the with statement when handling files in Python?
#
# --> the with statement in python is used to simpify the process of working with resources like files, ensuring proper management and cleanup of these resources. the with statement ensures that the file is automatically closed after its bloc of code is executed, even if an exception occours. the with statement is a powerful toll in python for handling files and other resources.
#
# 9. What is the difference between multithreading and multiprocessing?
#
# --> these two are techniques used in programming to achieve parallelism, allowing multiple tasks to run concurrently. multireading is better for tasks that are I/O- bound, while multiprocessing is better for cpu-bound tasks. the choice depends on the nature of the workload and the programming language used.
#
# 10. What are the advantages of using logging in a program?
#
# --> using logging in program offers several advantages, particularly when is comes to debugging, monitoring, and maintaining the application, error tracking, security and auditing.
#
# 11. What is memory management in Python?
#
# --> it refers to process of efficiently allocating, using and releasing memory during the execution of a program. python provides an automated and robust memory management system. whch includes garbage collection and dynamic memory allocation, making it easier for developers to handle memory without needing to explicitly allocate or free it.
#
# 12. What are the basic steps involved in exception handling in Python?
#
# --> the basic steps involved in exception handling are as follows: identify code that may raise exceptions, 2.use the try block to monitor for exceptions, 3.catch exceptions using the except block, 4.handle multiple exceptions, 6.perform cleanup using finally block, 7. raising exceptions manually, 8.create custom exceptions.
#
# 13. Why is memory management important in Python?
#
# --> memory management is crucial in python as in any programming language because it directly afects a program`s performance, efficency and reliability. it is essiental for ensuring that programs are effiecient , stable, and scalable. it enables portability an cross-platform use, suprting multireading and multiprocessing.
#
# 14. What is the role of try and except in exception handling?
#
# --> the try and except blockks are fundamental to exception handling in python. they allow developers to handle errors gracefully and prevent programs from crashing when unexcepted conditions occur. the try block contains code that might raise an exception and the role of except block is that it defines how to handle specific exceptions that occur in the try block.
#
# 15. How does Python's garbage collection system work?
#
# -->  here`s how it works:- garbage collections for circular reference then generational garbage collections divides objects into three generation generation o,1,2 and then collection processthat uses mark and sweep algorithm. and then managing garbage collection.
#
# 16. What is the purpose of the else block in exception handling?
#
# --> The purpose of the else block in exception handling is to define code that should execute only if no exceptions occour in the try block. it provides a way to seperate error-handling code from the code that should run when everything executes succesfully.
#
# 17. What are the common logging levels in Python?
#
# --> python`s logging module provides several predefined logging levels to catagorize log messeges based on their severity. common loging levels in python. debug level10, info level20, warning (level30), error (level40), crictical level50.
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# --> while os.fork() offers direct and low level process creation, multiprocessing provids a higher level, cross platform and more feature rich framework for managing processes in python. for most modern applications ,multiprocessing is the preffered approach due to its simplicity, portabilty, and built in utilities.
#
# 19. What is the importance of closing a file in Python?
#
# --> why closing a file is importanat:- releasing system resources, ensuring data entegrity, preventing errors, avoiding memory leaks, maintaining good code practices. closing flie in python is essential resource management, data integrity, preventing errors.
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
# --> the file.read() reads entire file or a specified number of characters. and the file.reading() reads single line from the file. both methods are useful in didffernet scenarios, so choosing the right one depends on your specific needs and file size.
#
# 21. What is the logging module in Python used for?
#
# --> The logging module in Python is used for tracking events that happen when some software runs. It is a powerful and flexible way to log messages from your applications, which can be useful for debugging, monitoring, and auditing purposes. It helps developers understand what is happening in their code and diagnose issues effectively.
#
# 22. What is the os module in Python used for in file handling?
#
# --> the os module in python is used for ineracting with the operating system, particularly for file and directory handling. it provides function to perform various file releated operations. sucha as. file manipulation deletes a file and renames a file os.rename, 2.directory operations, path handling with os.path, current working directory, environment variables.
#
# 23. What are the challenges associated with memory management in Python?
#
# --> memory management in python is mostly handled automatically by the python memory manager and garbage collector. challeneges:- garbage collection overhead, memory leaks, fragmentation, high memory consuption.
#
# 24. How do you raise an exception manually in Python?
#
# --> you can manually raise an exception using the raise statement. like:- raising a built in exception, raising a custom exception using raise without arguments.
#
# 25. Why is it important to use multithreading in certain applications?
#
# --> here are some key reasons why multireading is beneficial:- because of improve responsiveness exeample a gui based text editor can autosave a document without user input, efficient cpu utilization (reading writing files,user input handling), fster execution in multicore system, resources sharing and communication. for cpu-intensive tasks, multitasking is oftn a better choice in python.

# %% [markdown]
# #Practical Questions

# %%
#Q1
#open a file in write mode
("example.text", "w")
("\nthis is an additional line")
# Out:
# '\nthis is an additional line'

# %%
def read_file(file_name):
  try:
    with open(file_name, 'r') as file:
      for line in file:
        print(line, end='')
  except Exception as e:
    print(f"an error occured: {e}")

if __name__ == "__main__":
  file_name = "example.txt"
  read_file(file_name)
      for line in file:
        print(line, end='')
        except exception as e:
          print (f"an error occured: {e}")

          if __name__ == "__main__":
            file_name = "example.txt"
            read_file(file_name)
# Out:
#   File "<ipython-input-2-8c6494d1573f>", line 12
#     for line in file:
#     ^
# IndentationError: unexpected indent

# %%
#Q3
filename = "example.txt"
try:
    with open(filename, 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print(f"File '{filename}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File 'example.txt' does not exist.

# %%
#Q4
def copy_file_contents(source_file, destination_file):
    try:
        with open(source_file, 'r') as src:
            content = src.read()
        #open destination file i write mode
        with open(destination_file, 'w') as dest:
            dest.write(content)
    except Exception as e: # Corrected indentation here
        print(f"An error occurred: {e}")
    #specify the source and destination file names
    source_file = "source.txt"
    destination_file = "destination.txt"
    copy_file_contents(source_file, destination_file)

# %%
#Q5
def safe_divide(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
        return None
    else:
        return result

#example usage
numerator = 10
denominator = 0
result = safe_divide(numerator, denominator)
if result is not None:
    print(f"Result: {result}") # Added indentation (4 spaces)
# Out:
# Error: Division by zero is not allowed.

# %%
#Q6
import logging

#configure logging
logging.basicConfig(filename='error.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def divide_numbers(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError as e:  # Corrected indentation
        logging.error("Attempted to divide by zero: %s", e)

# Example usage
num1 = 10
num2 = 0
result = divide_numbers(num1, num2)
if result is not None:
    print(f"Result: {result}")
else:
    print("Error occurred. Check the log for details.")
# Out:
# ERROR:root:Attempted to divide by zero: division by zero
# Error occurred. Check the log for details.

# %%
#Q7
import logging

# configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s') # Changed 'basicconfig' to 'basicConfig'

#log messages at different levels
logging.debug('this is a debug message')
logging.info('this is an info message')
logging.warning('this is a warning message')
logging.error('this is an error message')
logging.critical('this is a critical message')
# Out:
# WARNING:root:this is a warning message
# ERROR:root:this is an error message
# CRITICAL:root:this is a critical message

# %%
#Q8
def open_file(file_name):
    try:
        # Attempt to open the file in read mode
        with open(file_name, 'r') as file:
            content = file.read()
            print("File content:")
            print(content)
    except FileNotFoundError:
        print(f"Error: The file '{file_name}' does not exist.")
    except PermissionError:
        print(f"Error: You do not have permission to access '{file_name}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
file_name = "example.txt"
open_file(file_name)
# Out:
# Error: The file 'example.txt' does not exist.

# %%
#Q9
#Open the file in read mode
try:
    with open('filename.txt', 'r') as file:
        lines = file.readlines()  # This reads all lines into a list

    # Strip newline characters from each line
    lines = [line.strip() for line in lines]

    # Now 'lines' contains all the lines from the file
    print(lines)
except FileNotFoundError:
    print("Error: The file 'filename.txt' does not exist in the current directory.")
# Out:
# Error: The file 'filename.txt' does not exist in the current directory.

# %%
#Q11
#Sample dictionary
my_dict = {
    'name': 'Alice',
    'age': 30,
    'city': 'New York'
}

# Function to access a key in the dictionary
def access_key(key):
    try:
        # Attempt to access the value associated with the key
        value = my_dict[key]
        print(f"The value for '{key}' is: {value}")
    except KeyError:
        # Handle the case where the key does not exist
        print(f"Error: The key '{key}' does not exist in the dictionary.")

# Test the function with a valid key
access_key('name')

# Test the function with an invalid key
access_key('country')
# Out:
# The value for 'name' is: Alice
# Error: The key 'country' does not exist in the dictionary.

# %%
#Q12
def perform_operations():
    try:
        # Get user input
        num1 = int(input("Enter the first number: "))
        num2 = int(input("Enter the second number: "))

        # Perform division
        result = num1 / num2
        print(f"The result of {num1} divided by {num2} is: {result}")

        # Attempt to add a string to an integer to raise TypeError
        invalid_operation = num1 + "string"

    except ValueError:
        print("Error: Please enter valid integers.")
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
    except TypeError:
        print("Error: Invalid operation. You cannot add a string to an integer.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    else:
        print("Operations completed successfully.")
    finally:
        print("Thank you for using the program!")

# Run the program
perform_operations()
# Out:
# Thank you for using the program!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-4493824e8eb7> in <cell line: 0>()
#      27
#      28 # Run the program
# ---> 29 perform_operations()
#
# <ipython-input-12-4493824e8eb7> in perform_operations()
#       3     try:
#       4         # Get user input
# ----> 5         num1 = int(input("Enter the first number: "))
#       6         num2 = int(input("Enter the second number: "))
#       7
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Q13
import os

file_path = 'example.txt'

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        print(content)
else:
    print(f"The file {file_path} does not exist.")
# Out:
# The file example.txt does not exist.

# %%
#Q14
import logging

# Configure the logging system
logging.basicConfig(
    level=logging.DEBUG,  # Set the logging level to DEBUG to capture all types of log messages
    format='%(asctime)s - %(levelname)s - %(message)s',  # Define the format of the log messages
    handlers=[
        logging.FileHandler("app.log"),  # Log messages to a file named 'app.log'
        logging.StreamHandler()  # Also log messages to the console
    ]
)

def divide_numbers(num1, num2):
    logging.info(f"Attempting to divide {num1} by {num2}")
    try:
        result = num1 / num2
        logging.info(f"Division successful: {result}")
        return result
    except ZeroDivisionError as e:
        logging.error(f"Error occurred: {e}")
        return None

if __name__ == "__main__":
    # Log an informational message
    logging.info("Program started")

    # Test the divide_numbers function
    divide_numbers(10, 2)  # This should log an informational message
    divide_numbers(10, 0)  # This should log an error message

    # Log an informational message indicating the end of the program
    logging.info("Program finished")
# Out:
# ERROR:root:Error occurred: division by zero

# %%
#Q15
# !pip install memory_profiler  # Install the memory_profiler package
#Q16
#pip install memory_profiler

from memory_profiler import profile

@profile
def generate_squares(n):
    """Generate a list of squares from 0 to n-1."""
    squares = []
    for i in range(n):
        squares.append(i * i)
    return squares

if __name__ == "__main__":
    result = generate_squares(1000000)
    print("Generated squares.")
# !python -m memory_profiler my_program.py  # Assuming 'my_program.py' contains your code
# Out:
# Collecting memory_profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory_profiler
# Successfully installed memory_profiler-0.61.0
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 847, in enable
#     sys.settrace(self.trace_memory_usage)
# ERROR: Could not find file <ipython-input-15-24c445e08a64>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 850, in disable
#     sys.settrace(self._original_trace_function)
# Generated squares.
# Could not find script my_program.py

# %%
#Q18
import logging
from logging.handlers import RotatingFileHandler

# Define the log file name and the maximum file size (1MB)
log_file = 'app.log'
max_file_size = 1 * 1024 * 1024  # 1 MB
backup_count = 5  # Number of backup files to keep

# Create a logger
logger = logging.getLogger('MyLogger')
logger.setLevel(logging.DEBUG)  # Set the logging level

# Create a rotating file handler
handler = RotatingFileHandler(log_file, maxBytes=max_file_size, backupCount=backup_count)
handler.setLevel(logging.DEBUG)  # Set the handler level

# Create a formatter and set it for the handler
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example usage
if __name__ == "__main__":
    for i in range(10000):
        logger.debug(f'This is a debug message {i}')
        logger.info(f'This is an info message {i}')
        logger.warning(f'This is a warning message {i}')
        logger.error(f'This is an error message {i}')
        logger.critical(f'This is a critical message {i}')
# Out:
# Streaming output truncated to the last 5000 lines.
# ERROR:MyLogger:This is an error message 3832
# CRITICAL:MyLogger:This is a critical message 3832
# DEBUG:MyLogger:This is a debug message 3833
# INFO:MyLogger:This is an info message 3833
# WARNING:MyLogger:This is a warning message 3833
# ERROR:MyLogger:This is an error message 3833
# CRITICAL:MyLogger:This is a critical message 3833
# DEBUG:MyLogger:This is a debug message 3834
# INFO:MyLogger:This is an info message 3834
# WARNING:MyLogger:This is a warning message 3834
# ERROR:MyLogger:This is an error message 3834
# CRITICAL:MyLogger:This is a critical message 3834
# DEBUG:MyLogger:This is a debug message 3835
# INFO:MyLogger:This is an info message 3835
# WARNING:MyLogger:This is a warning message 3835
# ERROR:MyLogger:This is an error message 3835
# CRITICAL:MyLogger:This is a critical message 3835
# DEBUG:MyLogger:This is a debug message 3836
# INFO:MyLogger:This is an info message 3836
# WARNING:MyLogger:This is a warning message 3836
# ERROR:MyLogger:This is an error message 3836
# CRITICAL:MyLogger:This is a critical message 3836
# DEBUG:MyLogger:This is a debug message 3837
# INFO:MyLogger:This is an info message 3837
# WARNING:MyLogger:This is a warning message 3837
# ERROR:MyLogger:This is an error message 3837
# CRITICAL:MyLogger:This is a critical message 3837
# DEBUG:MyLogger:This is a debug message 3838
# INFO:MyLogger:This is an info message 3838
# WARNING:MyLogger:This is a warning message 3838
# ERROR:MyLogger:This is an error message 3838
# CRITICAL:MyLogger:This is a critical message 3838
# DEBUG:MyLogger:This is a debug message 3839
# INFO:MyLogger:This is an info message 3839
# WARNING:MyLogger:This is a warning message 3839
# ERROR:MyLogger:This is an error message 3839
# CRITICAL:MyLogger:This is a critical message 3839
# DEBUG:MyLogger:This is a debug message 3840
# INFO:MyLogger:This is an info message 3840
# WARNING:MyLogger:This is a warning message 3840
# ERROR:MyLogger:This is an error message 3840
# CRITICAL:MyLogger:This is a critical message 3840
# DEBUG:MyLogger:This is a debug message 3841
# INFO:MyLogger:This is an info message 3841
# WARNING:MyLogger:This is a warning message 3841
# ERROR:MyLogger:This is an error message 3841
# CRITICAL:MyLogger:This is a critical message 3841
# DEBUG:MyLogger:This is a debug message 3842
# INFO:MyLogger:This is an info message 3842
# WARNING:MyLogger:This is a warning message 3842
# ERROR:MyLogger:This is an error message 3842
# CRITICAL:MyLogger:This is a critical message 3842
# DEBUG:MyLogger:This is a debug message 3843
# INFO:MyLogger:This is an info message 3843
# WARNING:MyLogger:This is a warning message 3843
# ERROR:MyLogger:This is an error message 3843
# CRITICAL:MyLogger:This is a critical message 3843
# DEBUG:MyLogger:This is a debug message 3844
# INFO:MyLogger:This is an info message 3844
# WARNING:MyLogger:This is a warning message 3844
# ERROR:MyLogger:This is an error message 3844
# CRITICAL:MyLogger:This is a critical message 3844
# DEBUG:MyLogger:This is a debug message 3845
# INFO:MyLogger:This is an info message 3845
# WARNING:MyLogger:This is a warning message 3845
# ERROR:MyLogger:This is an error message 3845
# CRITICAL:MyLogger:This is a critical message 3845
# DEBUG:MyLogger:This is a debug message 3846
# INFO:MyLogger:This is an info message 3846
# WARNING:MyLogger:This is a warning message 3846
# ERROR:MyLogger:This is an error message 3846
# CRITICAL:MyLogger:This is a critical message 3846
# DEBUG:MyLogger:This is a debug message 3847
# INFO:MyLogger:This is an info message 3847
# WARNING:MyLogger:This is a warning message 3847
# ERROR:MyLogger:This is an error message 3847
# CRITICAL:MyLogger:This is a critical message 3847
# DEBUG:MyLogger:This is a debug message 3848
# INFO:MyLogger:This is an info message 3848
# WARNING:MyLogger:This is a warning message 3848
# ERROR:MyLogger:This is an error message 3848
# CRITICAL:MyLogger:This is a critical message 3848
# DEBUG:MyLogger:This is a debug message 3849
# INFO:MyLogger:This is an info message 3849
# WARNING:MyLogger:This is a warning message 3849
# ERROR:MyLogger:This is an error message 3849
# CRITICAL:MyLogger:This is a critical message 3849
# DEBUG:MyLogger:This is a debug message 3850
# INFO:MyLogger:This is an info message 3850
# WARNING:MyLogger:This is a warning message 3850
# ERROR:MyLogger:This is an error message 3850
# CRITICAL:MyLogger:This is a critical message 3850
# DEBUG:MyLogger:This is a debug message 3851
# INFO:MyLogger:This is an info message 3851
# WARNING:MyLogger:This is a warning message 3851
# ERROR:MyLogger:This is an error message 3851
# CRITICAL:MyLogger:This is a critical message 3851
# DEBUG:MyLogger:This is a debug message 3852
# INFO:MyLogger:This is an info message 3852
# WARNING:MyLogger:This is a warning message 3852
# ERROR:MyLogger:This is an error message 3852
# CRITICAL:MyLogger:This is a critical message 3852
# DEBUG:MyLogger:This is a debug message 3853
# INFO:MyLogger:This is an info message 3853
# WARNING:MyLogger:This is a warning message 3853
# ERROR:MyLogger:This is an error message 3853
# CRITICAL:MyLogger:This is a critical message 3853
# DEBUG:MyLogger:This is a debug message 3854
# INFO:MyLogger:This is an info message 3854
# WARNING:MyLogger:This is a warning message 3854
# ERROR:MyLogger:This is an error message 3854
# CRITICAL:MyLogger:This is a critical message 3854
# DEBUG:MyLogger:This is a debug message 3855
# INFO:MyLogger:This is an info message 3855
# WARNING:MyLogger:This is a warning message 3855
# ERROR:MyLogger:This is an error message 3855
# CRITICAL:MyLogger:This is a critical message 3855
# DEBUG:MyLogger:This is a debug message 3856
# INFO:MyLogger:This is an info message 3856
# WARNING:MyLogger:This is a warning message 3856
# ERROR:MyLogger:This is an error message 3856
# CRITICAL:MyLogger:This is a critical message 3856
# DEBUG:MyLogger:This is a debug message 3857
# INFO:MyLogger:This is an info message 3857
# WARNING:MyLogger:This is a warning message 3857
# ERROR:MyLogger:This is an error message 3857
# CRITICAL:MyLogger:This is a critical message 3857
# DEBUG:MyLogger:This is a debug message 3858
# INFO:MyLogger:This is an info message 3858
# WARNING:MyLogger:This is a warning message 3858
# ERROR:MyLogger:This is an error message 3858
# CRITICAL:MyLogger:This is a critical message 3858
# DEBUG:MyLogger:This is a debug message 3859
# INFO:MyLogger:This is an info message 3859
# WARNING:MyLogger:This is a warning message 3859
# ERROR:MyLogger:This is an error message 3859
# CRITICAL:MyLogger:This is a critical message 3859
# DEBUG:MyLogger:This is a debug message 3860
# INFO:MyLogger:This is an info message 3860
# WARNING:MyLogger:This is a warning message 3860
# ERROR:MyLogger:This is an error message 3860
# CRITICAL:MyLogger:This is a critical message 3860
# DEBUG:MyLogger:This is a debug message 3861
# INFO:MyLogger:This is an info message 3861
# WARNING:MyLogger:This is a warning message 3861
# ERROR:MyLogger:This is an error message 3861
# CRITICAL:MyLogger:This is a critical message 3861
# DEBUG:MyLogger:This is a debug message 3862
# INFO:MyLogger:This is an info message 3862
# WARNING:MyLogger:This is a warning message 3862
# ERROR:MyLogger:This is an error message 3862
# CRITICAL:MyLogger:This is a critical message 3862
# DEBUG:MyLogger:This is a debug message 3863
# INFO:MyLogger:This is an info message 3863
# WARNING:MyLogger:This is a warning message 3863
# ERROR:MyLogger:This is an error message 3863
# CRITICAL:MyLogger:This is a critical message 3863
# DEBUG:MyLogger:This is a debug message 3864
# INFO:MyLogger:This is an info message 3864
# WARNING:MyLogger:This is a warning message 3864
# ERROR:MyLogger:This is an error message 3864
# CRITICAL:MyLogger:This is a critical message 3864
# DEBUG:MyLogger:This is a debug message 3865
# INFO:MyLogger:This is an info message 3865
# WARNING:MyLogger:This is a warning message 3865
# ERROR:MyLogger:This is an error message 3865
# CRITICAL:MyLogger:This is a critical message 3865
# DEBUG:MyLogger:This is a debug message 3866
# INFO:MyLogger:This is an info message 3866
# WARNING:MyLogger:This is a warning message 3866
# ERROR:MyLogger:This is an error message 3866
# CRITICAL:MyLogger:This is a critical message 3866
# DEBUG:MyLogger:This is a debug message 3867
# INFO:MyLogger:This is an info message 3867
# WARNING:MyLogger:This is a warning message 3867
# ERROR:MyLogger:This is an error message 3867
# CRITICAL:MyLogger:This is a critical message 3867
# DEBUG:MyLogger:This is a debug message 3868
# INFO:MyLogger:This is an info message 3868
# WARNING:MyLogger:This is a warning message 3868
# ERROR:MyLogger:This is an error message 3868
# CRITICAL:MyLogger:This is a critical message 3868
# DEBUG:MyLogger:This is a debug message 3869
# INFO:MyLogger:This is an info message 3869
# WARNING:MyLogger:This is a warning message 3869
# ERROR:MyLogger:This is an error message 3869
# CRITICAL:MyLogger:This is a critical message 3869
# DEBUG:MyLogger:This is a debug message 3870
# INFO:MyLogger:This is an info message 3870
# WARNING:MyLogger:This is a warning message 3870
# ERROR:MyLogger:This is an error message 3870
# CRITICAL:MyLogger:This is a critical message 3870
# DEBUG:MyLogger:This is a debug message 3871
# INFO:MyLogger:This is an info message 3871
# WARNING:MyLogger:This is a warning message 3871
# ERROR:MyLogger:This is an error message 3871
# CRITICAL:MyLogger:This is a critical message 3871
# DEBUG:MyLogger:This is a debug message 3872
# INFO:MyLogger:This is an info message 3872
# WARNING:MyLogger:This is a warning message 3872
# ERROR:MyLogger:This is an error message 3872
# CRITICAL:MyLogger:This is a critical message 3872
# DEBUG:MyLogger:This is a debug message 3873
# INFO:MyLogger:This is an info message 3873
# WARNING:MyLogger:This is a warning message 3873
# ERROR:MyLogger:This is an error message 3873
# CRITICAL:MyLogger:This is a critical message 3873
# DEBUG:MyLogger:This is a debug message 3874
# INFO:MyLogger:This is an info message 3874
# WARNING:MyLogger:This is a warning message 3874
# ERROR:MyLogger:This is an error message 3874
# CRITICAL:MyLogger:This is a critical message 3874
# DEBUG:MyLogger:This is a debug message 3875
# INFO:MyLogger:This is an info message 3875
# WARNING:MyLogger:This is a warning message 3875
# ERROR:MyLogger:This is an error message 3875
# CRITICAL:MyLogger:This is a critical message 3875
# DEBUG:MyLogger:This is a debug message 3876
# INFO:MyLogger:This is an info message 3876
# WARNING:MyLogger:This is a warning message 3876
# ERROR:MyLogger:This is an error message 3876
# CRITICAL:MyLogger:This is a critical message 3876
# DEBUG:MyLogger:This is a debug message 3877
# INFO:MyLogger:This is an info message 3877
# WARNING:MyLogger:This is a warning message 3877
# ERROR:MyLogger:This is an error message 3877
# CRITICAL:MyLogger:This is a critical message 3877
# DEBUG:MyLogger:This is a debug message 3878
# INFO:MyLogger:This is an info message 3878
# WARNING:MyLogger:This is a warning message 3878
# ERROR:MyLogger:This is an error message 3878
# CRITICAL:MyLogger:This is a critical message 3878
# DEBUG:MyLogger:This is a debug message 3879
# INFO:MyLogger:This is an info message 3879
# WARNING:MyLogger:This is a warning message 3879
# ERROR:MyLogger:This is an error message 3879
# CRITICAL:MyLogger:This is a critical message 3879
# DEBUG:MyLogger:This is a debug message 3880
# INFO:MyLogger:This is an info message 3880
# WARNING:MyLogger:This is a warning message 3880
# ERROR:MyLogger:This is an error message 3880
# CRITICAL:MyLogger:This is a critical message 3880
# DEBUG:MyLogger:This is a debug message 3881
# INFO:MyLogger:This is an info message 3881
# WARNING:MyLogger:This is a warning message 3881
# ERROR:MyLogger:This is an error message 3881
# CRITICAL:MyLogger:This is a critical message 3881
# DEBUG:MyLogger:This is a debug message 3882
# INFO:MyLogger:This is an info message 3882
# WARNING:MyLogger:This is a warning message 3882
# ERROR:MyLogger:This is an error message 3882
# CRITICAL:MyLogger:This is a critical message 3882
# DEBUG:MyLogger:This is a debug message 3883
# INFO:MyLogger:This is an info message 3883
# WARNING:MyLogger:This is a warning message 3883
# ERROR:MyLogger:This is an error message 3883
# CRITICAL:MyLogger:This is a critical message 3883
# DEBUG:MyLogger:This is a debug message 3884
# INFO:MyLogger:This is an info message 3884
# WARNING:MyLogger:This is a warning message 3884
# ERROR:MyLogger:This is an error message 3884
# CRITICAL:MyLogger:This is a critical message 3884
# DEBUG:MyLogger:This is a debug message 3885
# INFO:MyLogger:This is an info message 3885
# WARNING:MyLogger:This is a warning message 3885
# ERROR:MyLogger:This is an error message 3885
# CRITICAL:MyLogger:This is a critical message 3885
# DEBUG:MyLogger:This is a debug message 3886
# INFO:MyLogger:This is an info message 3886
# WARNING:MyLogger:This is a warning message 3886
# ERROR:MyLogger:This is an error message 3886
# CRITICAL:MyLogger:This is a critical message 3886
# DEBUG:MyLogger:This is a debug message 3887
# INFO:MyLogger:This is an info message 3887
# WARNING:MyLogger:This is a warning message 3887
# ERROR:MyLogger:This is an error message 3887
# CRITICAL:MyLogger:This is a critical message 3887
# DEBUG:MyLogger:This is a debug message 3888
# INFO:MyLogger:This is an info message 3888
# WARNING:MyLogger:This is a warning message 3888
# ERROR:MyLogger:This is an error message 3888
# CRITICAL:MyLogger:This is a critical message 3888
# DEBUG:MyLogger:This is a debug message 3889
# INFO:MyLogger:This is an info message 3889
# WARNING:MyLogger:This is a warning message 3889
# ERROR:MyLogger:This is an error message 3889
# CRITICAL:MyLogger:This is a critical message 3889
# DEBUG:MyLogger:This is a debug message 3890
# INFO:MyLogger:This is an info message 3890
# WARNING:MyLogger:This is a warning message 3890
# ERROR:MyLogger:This is an error message 3890
# CRITICAL:MyLogger:This is a critical message 3890
# DEBUG:MyLogger:This is a debug message 3891
# INFO:MyLogger:This is an info message 3891
# WARNING:MyLogger:This is a warning message 3891
# ERROR:MyLogger:This is an error message 3891
# CRITICAL:MyLogger:This is a critical message 3891
# DEBUG:MyLogger:This is a debug message 3892
# INFO:MyLogger:This is an info message 3892
# WARNING:MyLogger:This is a warning message 3892
# ERROR:MyLogger:This is an error message 3892
# CRITICAL:MyLogger:This is a critical message 3892
# DEBUG:MyLogger:This is a debug message 3893
# INFO:MyLogger:This is an info message 3893
# WARNING:MyLogger:This is a warning message 3893
# ERROR:MyLogger:This is an error message 3893
# CRITICAL:MyLogger:This is a critical message 3893
# DEBUG:MyLogger:This is a debug message 3894
# INFO:MyLogger:This is an info message 3894
# WARNING:MyLogger:This is a warning message 3894
# ERROR:MyLogger:This is an error message 3894
# CRITICAL:MyLogger:This is a critical message 3894
# DEBUG:MyLogger:This is a debug message 3895
# INFO:MyLogger:This is an info message 3895
# WARNING:MyLogger:This is a warning message 3895
# ERROR:MyLogger:This is an error message 3895
# CRITICAL:MyLogger:This is a critical message 3895
# DEBUG:MyLogger:This is a debug message 3896
# INFO:MyLogger:This is an info message 3896
# WARNING:MyLogger:This is a warning message 3896
# ERROR:MyLogger:This is an error message 3896
# CRITICAL:MyLogger:This is a critical message 3896
# DEBUG:MyLogger:This is a debug message 3897
# INFO:MyLogger:This is an info message 3897
# WARNING:MyLogger:This is a warning message 3897
# ERROR:MyLogger:This is an error message 3897
# CRITICAL:MyLogger:This is a critical message 3897
# DEBUG:MyLogger:This is a debug message 3898
# INFO:MyLogger:This is an info message 3898
# WARNING:MyLogger:This is a warning message 3898
# ERROR:MyLogger:This is an error message 3898
# CRITICAL:MyLogger:This is a critical message 3898
# DEBUG:MyLogger:This is a debug message 3899
# INFO:MyLogger:This is an info message 3899
# WARNING:MyLogger:This is a warning message 3899
# ERROR:MyLogger:This is an error message 3899
# CRITICAL:MyLogger:This is a critical message 3899
# DEBUG:MyLogger:This is a debug message 3900
# INFO:MyLogger:This is an info message 3900
# WARNING:MyLogger:This is a warning message 3900
# ERROR:MyLogger:This is an error message 3900
# CRITICAL:MyLogger:This is a critical message 3900
# DEBUG:MyLogger:This is a debug message 3901
# INFO:MyLogger:This is an info message 3901
# WARNING:MyLogger:This is a warning message 3901
# ERROR:MyLogger:This is an error message 3901
# CRITICAL:MyLogger:This is a critical message 3901
# DEBUG:MyLogger:This is a debug message 3902
# INFO:MyLogger:This is an info message 3902
# WARNING:MyLogger:This is a warning message 3902
# ERROR:MyLogger:This is an error message 3902
# CRITICAL:MyLogger:This is a critical message 3902
# DEBUG:MyLogger:This is a debug message 3903
# INFO:MyLogger:This is an info message 3903
# WARNING:MyLogger:This is a warning message 3903
# ERROR:MyLogger:This is an error message 3903
# CRITICAL:MyLogger:This is a critical message 3903
# DEBUG:MyLogger:This is a debug message 3904
# INFO:MyLogger:This is an info message 3904
# WARNING:MyLogger:This is a warning message 3904
# ERROR:MyLogger:This is an error message 3904
# CRITICAL:MyLogger:This is a critical message 3904
# DEBUG:MyLogger:This is a debug message 3905
# INFO:MyLogger:This is an info message 3905
# WARNING:MyLogger:This is a warning message 3905
# ERROR:MyLogger:This is an error message 3905
# CRITICAL:MyLogger:This is a critical message 3905
# DEBUG:MyLogger:This is a debug message 3906
# INFO:MyLogger:This is an info message 3906
# WARNING:MyLogger:This is a warning message 3906
# ERROR:MyLogger:This is an error message 3906
# CRITICAL:MyLogger:This is a critical message 3906
# DEBUG:MyLogger:This is a debug message 3907
# INFO:MyLogger:This is an info message 3907
# WARNING:MyLogger:This is a warning message 3907
# ERROR:MyLogger:This is an error message 3907
# CRITICAL:MyLogger:This is a critical message 3907
# DEBUG:MyLogger:This is a debug message 3908
# INFO:MyLogger:This is an info message 3908
# WARNING:MyLogger:This is a warning message 3908
# ERROR:MyLogger:This is an error message 3908
# CRITICAL:MyLogger:This is a critical message 3908
# DEBUG:MyLogger:This is a debug message 3909
# INFO:MyLogger:This is an info message 3909
# WARNING:MyLogger:This is a warning message 3909
# ERROR:MyLogger:This is an error message 3909
# CRITICAL:MyLogger:This is a critical message 3909
# DEBUG:MyLogger:This is a debug message 3910
# INFO:MyLogger:This is an info message 3910
# WARNING:MyLogger:This is a warning message 3910
# ERROR:MyLogger:This is an error message 3910
# CRITICAL:MyLogger:This is a critical message 3910
# DEBUG:MyLogger:This is a debug message 3911
# INFO:MyLogger:This is an info message 3911
# WARNING:MyLogger:This is a warning message 3911
# ERROR:MyLogger:This is an error message 3911
# CRITICAL:MyLogger:This is a critical message 3911
# DEBUG:MyLogger:This is a debug message 3912
# INFO:MyLogger:This is an info message 3912
# WARNING:MyLogger:This is a warning message 3912
# ERROR:MyLogger:This is an error message 3912
# CRITICAL:MyLogger:This is a critical message 3912
# DEBUG:MyLogger:This is a debug message 3913
# INFO:MyLogger:This is an info message 3913
# WARNING:MyLogger:This is a warning message 3913
# ERROR:MyLogger:This is an error message 3913
# CRITICAL:MyLogger:This is a critical message 3913
# DEBUG:MyLogger:This is a debug message 3914
# INFO:MyLogger:This is an info message 3914
# WARNING:MyLogger:This is a warning message 3914
# ERROR:MyLogger:This is an error message 3914
# CRITICAL:MyLogger:This is a critical message 3914
# DEBUG:MyLogger:This is a debug message 3915
# INFO:MyLogger:This is an info message 3915
# WARNING:MyLogger:This is a warning message 3915
# ERROR:MyLogger:This is an error message 3915
# CRITICAL:MyLogger:This is a critical message 3915
# DEBUG:MyLogger:This is a debug message 3916
# INFO:MyLogger:This is an info message 3916
# WARNING:MyLogger:This is a warning message 3916
# ERROR:MyLogger:This is an error message 3916
# CRITICAL:MyLogger:This is a critical message 3916
# DEBUG:MyLogger:This is a debug message 3917
# INFO:MyLogger:This is an info message 3917
# WARNING:MyLogger:This is a warning message 3917
# ERROR:MyLogger:This is an error message 3917
# CRITICAL:MyLogger:This is a critical message 3917
# DEBUG:MyLogger:This is a debug message 3918
# INFO:MyLogger:This is an info message 3918
# WARNING:MyLogger:This is a warning message 3918
# ERROR:MyLogger:This is an error message 3918
# CRITICAL:MyLogger:This is a critical message 3918
# DEBUG:MyLogger:This is a debug message 3919
# INFO:MyLogger:This is an info message 3919
# WARNING:MyLogger:This is a warning message 3919
# ERROR:MyLogger:This is an error message 3919
# CRITICAL:MyLogger:This is a critical message 3919
# DEBUG:MyLogger:This is a debug message 3920
# INFO:MyLogger:This is an info message 3920
# WARNING:MyLogger:This is a warning message 3920
# ERROR:MyLogger:This is an error message 3920
# CRITICAL:MyLogger:This is a critical message 3920
# DEBUG:MyLogger:This is a debug message 3921
# INFO:MyLogger:This is an info message 3921
# WARNING:MyLogger:This is a warning message 3921
# ERROR:MyLogger:This is an error message 3921
# CRITICAL:MyLogger:This is a critical message 3921
# DEBUG:MyLogger:This is a debug message 3922
# INFO:MyLogger:This is an info message 3922
# WARNING:MyLogger:This is a warning message 3922
# ERROR:MyLogger:This is an error message 3922
# CRITICAL:MyLogger:This is a critical message 3922
# DEBUG:MyLogger:This is a debug message 3923
# INFO:MyLogger:This is an info message 3923
# WARNING:MyLogger:This is a warning message 3923
# ERROR:MyLogger:This is an error message 3923
# CRITICAL:MyLogger:This is a critical message 3923
# DEBUG:MyLogger:This is a debug message 3924
# INFO:MyLogger:This is an info message 3924
# WARNING:MyLogger:This is a warning message 3924
# ERROR:MyLogger:This is an error message 3924
# CRITICAL:MyLogger:This is a critical message 3924
# DEBUG:MyLogger:This is a debug message 3925
# INFO:MyLogger:This is an info message 3925
# WARNING:MyLogger:This is a warning message 3925
# ERROR:MyLogger:This is an error message 3925
# CRITICAL:MyLogger:This is a critical message 3925
# DEBUG:MyLogger:This is a debug message 3926
# INFO:MyLogger:This is an info message 3926
# WARNING:MyLogger:This is a warning message 3926
# ERROR:MyLogger:This is an error message 3926
# CRITICAL:MyLogger:This is a critical message 3926
# DEBUG:MyLogger:This is a debug message 3927
# INFO:MyLogger:This is an info message 3927
# WARNING:MyLogger:This is a warning message 3927
# ERROR:MyLogger:This is an error message 3927
# CRITICAL:MyLogger:This is a critical message 3927
# DEBUG:MyLogger:This is a debug message 3928
# INFO:MyLogger:This is an info message 3928
# WARNING:MyLogger:This is a warning message 3928
# ERROR:MyLogger:This is an error message 3928
# CRITICAL:MyLogger:This is a critical message 3928
# DEBUG:MyLogger:This is a debug message 3929
# INFO:MyLogger:This is an info message 3929
# WARNING:MyLogger:This is a warning message 3929
# ERROR:MyLogger:This is an error message 3929
# CRITICAL:MyLogger:This is a critical message 3929
# DEBUG:MyLogger:This is a debug message 3930
# INFO:MyLogger:This is an info message 3930
# WARNING:MyLogger:This is a warning message 3930
# ERROR:MyLogger:This is an error message 3930
# CRITICAL:MyLogger:This is a critical message 3930
# DEBUG:MyLogger:This is a debug message 3931
# INFO:MyLogger:This is an info message 3931
# WARNING:MyLogger:This is a warning message 3931
# ERROR:MyLogger:This is an error message 3931
# CRITICAL:MyLogger:This is a critical message 3931
# DEBUG:MyLogger:This is a debug message 3932
# INFO:MyLogger:This is an info message 3932
# WARNING:MyLogger:This is a warning message 3932
# ERROR:MyLogger:This is an error message 3932
# CRITICAL:MyLogger:This is a critical message 3932
# DEBUG:MyLogger:This is a debug message 3933
# INFO:MyLogger:This is an info message 3933
# WARNING:MyLogger:This is a warning message 3933
# ERROR:MyLogger:This is an error message 3933
# CRITICAL:MyLogger:This is a critical message 3933
# DEBUG:MyLogger:This is a debug message 3934
# INFO:MyLogger:This is an info message 3934
# WARNING:MyLogger:This is a warning message 3934
# ERROR:MyLogger:This is an error message 3934
# CRITICAL:MyLogger:This is a critical message 3934
# DEBUG:MyLogger:This is a debug message 3935
# INFO:MyLogger:This is an info message 3935
# WARNING:MyLogger:This is a warning message 3935
# ERROR:MyLogger:This is an error message 3935
# CRITICAL:MyLogger:This is a critical message 3935
# DEBUG:MyLogger:This is a debug message 3936
# INFO:MyLogger:This is an info message 3936
# WARNING:MyLogger:This is a warning message 3936
# ERROR:MyLogger:This is an error message 3936
# CRITICAL:MyLogger:This is a critical message 3936
# DEBUG:MyLogger:This is a debug message 3937
# INFO:MyLogger:This is an info message 3937
# WARNING:MyLogger:This is a warning message 3937
# ERROR:MyLogger:This is an error message 3937
# CRITICAL:MyLogger:This is a critical message 3937
# DEBUG:MyLogger:This is a debug message 3938
# INFO:MyLogger:This is an info message 3938
# WARNING:MyLogger:This is a warning message 3938
# ERROR:MyLogger:This is an error message 3938
# CRITICAL:MyLogger:This is a critical message 3938
# DEBUG:MyLogger:This is a debug message 3939
# INFO:MyLogger:This is an info message 3939
# WARNING:MyLogger:This is a warning message 3939
# ERROR:MyLogger:This is an error message 3939
# CRITICAL:MyLogger:This is a critical message 3939
# DEBUG:MyLogger:This is a debug message 3940
# INFO:MyLogger:This is an info message 3940
# WARNING:MyLogger:This is a warning message 3940
# ERROR:MyLogger:This is an error message 3940
# CRITICAL:MyLogger:This is a critical message 3940
# DEBUG:MyLogger:This is a debug message 3941
# INFO:MyLogger:This is an info message 3941
# WARNING:MyLogger:This is a warning message 3941
# ERROR:MyLogger:This is an error message 3941
# CRITICAL:MyLogger:This is a critical message 3941
# DEBUG:MyLogger:This is a debug message 3942
# INFO:MyLogger:This is an info message 3942
# WARNING:MyLogger:This is a warning message 3942
# ERROR:MyLogger:This is an error message 3942
# CRITICAL:MyLogger:This is a critical message 3942
# DEBUG:MyLogger:This is a debug message 3943
# INFO:MyLogger:This is an info message 3943
# WARNING:MyLogger:This is a warning message 3943
# ERROR:MyLogger:This is an error message 3943
# CRITICAL:MyLogger:This is a critical message 3943
# DEBUG:MyLogger:This is a debug message 3944
# INFO:MyLogger:This is an info message 3944
# WARNING:MyLogger:This is a warning message 3944
# ERROR:MyLogger:This is an error message 3944
# CRITICAL:MyLogger:This is a critical message 3944
# DEBUG:MyLogger:This is a debug message 3945
# INFO:MyLogger:This is an info message 3945
# WARNING:MyLogger:This is a warning message 3945
# ERROR:MyLogger:This is an error message 3945
# CRITICAL:MyLogger:This is a critical message 3945
# DEBUG:MyLogger:This is a debug message 3946
# INFO:MyLogger:This is an info message 3946
# WARNING:MyLogger:This is a warning message 3946
# ERROR:MyLogger:This is an error message 3946
# CRITICAL:MyLogger:This is a critical message 3946
# DEBUG:MyLogger:This is a debug message 3947
# INFO:MyLogger:This is an info message 3947
# WARNING:MyLogger:This is a warning message 3947
# ERROR:MyLogger:This is an error message 3947
# CRITICAL:MyLogger:This is a critical message 3947
# DEBUG:MyLogger:This is a debug message 3948
# INFO:MyLogger:This is an info message 3948
# WARNING:MyLogger:This is a warning message 3948
# ERROR:MyLogger:This is an error message 3948
# CRITICAL:MyLogger:This is a critical message 3948
# DEBUG:MyLogger:This is a debug message 3949
# INFO:MyLogger:This is an info message 3949
# WARNING:MyLogger:This is a warning message 3949
# ERROR:MyLogger:This is an error message 3949
# CRITICAL:MyLogger:This is a critical message 3949
# DEBUG:MyLogger:This is a debug message 3950
# INFO:MyLogger:This is an info message 3950
# WARNING:MyLogger:This is a warning message 3950
# ERROR:MyLogger:This is an error message 3950
# CRITICAL:MyLogger:This is a critical message 3950
# DEBUG:MyLogger:This is a debug message 3951
# INFO:MyLogger:This is an info message 3951
# WARNING:MyLogger:This is a warning message 3951
# ERROR:MyLogger:This is an error message 3951
# CRITICAL:MyLogger:This is a critical message 3951
# DEBUG:MyLogger:This is a debug message 3952
# INFO:MyLogger:This is an info message 3952
# WARNING:MyLogger:This is a warning message 3952
# ERROR:MyLogger:This is an error message 3952
# CRITICAL:MyLogger:This is a critical message 3952
# DEBUG:MyLogger:This is a debug message 3953
# INFO:MyLogger:This is an info message 3953
# WARNING:MyLogger:This is a warning message 3953
# ERROR:MyLogger:This is an error message 3953
# CRITICAL:MyLogger:This is a critical message 3953
# DEBUG:MyLogger:This is a debug message 3954
# INFO:MyLogger:This is an info message 3954
# WARNING:MyLogger:This is a warning message 3954
# ERROR:MyLogger:This is an error message 3954
# CRITICAL:MyLogger:This is a critical message 3954
# DEBUG:MyLogger:This is a debug message 3955
# INFO:MyLogger:This is an info message 3955
# WARNING:MyLogger:This is a warning message 3955
# ERROR:MyLogger:This is an error message 3955
# CRITICAL:MyLogger:This is a critical message 3955
# DEBUG:MyLogger:This is a debug message 3956
# INFO:MyLogger:This is an info message 3956
# WARNING:MyLogger:This is a warning message 3956
# ERROR:MyLogger:This is an error message 3956
# CRITICAL:MyLogger:This is a critical message 3956
# DEBUG:MyLogger:This is a debug message 3957
# INFO:MyLogger:This is an info message 3957
# WARNING:MyLogger:This is a warning message 3957
# ERROR:MyLogger:This is an error message 3957
# CRITICAL:MyLogger:This is a critical message 3957
# DEBUG:MyLogger:This is a debug message 3958
# INFO:MyLogger:This is an info message 3958
# WARNING:MyLogger:This is a warning message 3958
# ERROR:MyLogger:This is an error message 3958
# CRITICAL:MyLogger:This is a critical message 3958
# DEBUG:MyLogger:This is a debug message 3959
# INFO:MyLogger:This is an info message 3959
# WARNING:MyLogger:This is a warning message 3959
# ERROR:MyLogger:This is an error message 3959
# CRITICAL:MyLogger:This is a critical message 3959
# DEBUG:MyLogger:This is a debug message 3960
# INFO:MyLogger:This is an info message 3960
# WARNING:MyLogger:This is a warning message 3960
# ERROR:MyLogger:This is an error message 3960
# CRITICAL:MyLogger:This is a critical message 3960
# DEBUG:MyLogger:This is a debug message 3961
# INFO:MyLogger:This is an info message 3961
# WARNING:MyLogger:This is a warning message 3961
# ERROR:MyLogger:This is an error message 3961
# CRITICAL:MyLogger:This is a critical message 3961
# DEBUG:MyLogger:This is a debug message 3962
# INFO:MyLogger:This is an info message 3962
# WARNING:MyLogger:This is a warning message 3962
# ERROR:MyLogger:This is an error message 3962
# CRITICAL:MyLogger:This is a critical message 3962
# DEBUG:MyLogger:This is a debug message 3963
# INFO:MyLogger:This is an info message 3963
# WARNING:MyLogger:This is a warning message 3963
# ERROR:MyLogger:This is an error message 3963
# CRITICAL:MyLogger:This is a critical message 3963
# DEBUG:MyLogger:This is a debug message 3964
# INFO:MyLogger:This is an info message 3964
# WARNING:MyLogger:This is a warning message 3964
# ERROR:MyLogger:This is an error message 3964
# CRITICAL:MyLogger:This is a critical message 3964
# DEBUG:MyLogger:This is a debug message 3965
# INFO:MyLogger:This is an info message 3965
# WARNING:MyLogger:This is a warning message 3965
# ERROR:MyLogger:This is an error message 3965
# CRITICAL:MyLogger:This is a critical message 3965
# DEBUG:MyLogger:This is a debug message 3966
# INFO:MyLogger:This is an info message 3966
# WARNING:MyLogger:This is a warning message 3966
# ERROR:MyLogger:This is an error message 3966
# CRITICAL:MyLogger:This is a critical message 3966
# DEBUG:MyLogger:This is a debug message 3967
# INFO:MyLogger:This is an info message 3967
# WARNING:MyLogger:This is a warning message 3967
# ERROR:MyLogger:This is an error message 3967
# CRITICAL:MyLogger:This is a critical message 3967
# DEBUG:MyLogger:This is a debug message 3968
# INFO:MyLogger:This is an info message 3968
# WARNING:MyLogger:This is a warning message 3968
# ERROR:MyLogger:This is an error message 3968
# CRITICAL:MyLogger:This is a critical message 3968
# DEBUG:MyLogger:This is a debug message 3969
# INFO:MyLogger:This is an info message 3969
# WARNING:MyLogger:This is a warning message 3969
# ERROR:MyLogger:This is an error message 3969
# CRITICAL:MyLogger:This is a critical message 3969
# DEBUG:MyLogger:This is a debug message 3970
# INFO:MyLogger:This is an info message 3970
# WARNING:MyLogger:This is a warning message 3970
# ERROR:MyLogger:This is an error message 3970
# CRITICAL:MyLogger:This is a critical message 3970
# DEBUG:MyLogger:This is a debug message 3971
# INFO:MyLogger:This is an info message 3971
# WARNING:MyLogger:This is a warning message 3971
# ERROR:MyLogger:This is an error message 3971
# CRITICAL:MyLogger:This is a critical message 3971
# DEBUG:MyLogger:This is a debug message 3972
# INFO:MyLogger:This is an info message 3972
# WARNING:MyLogger:This is a warning message 3972
# ERROR:MyLogger:This is an error message 3972
# CRITICAL:MyLogger:This is a critical message 3972
# DEBUG:MyLogger:This is a debug message 3973
# INFO:MyLogger:This is an info message 3973
# WARNING:MyLogger:This is a warning message 3973
# ERROR:MyLogger:This is an error message 3973
# CRITICAL:MyLogger:This is a critical message 3973
# DEBUG:MyLogger:This is a debug message 3974
# INFO:MyLogger:This is an info message 3974
# WARNING:MyLogger:This is a warning message 3974
# ERROR:MyLogger:This is an error message 3974
# CRITICAL:MyLogger:This is a critical message 3974
# DEBUG:MyLogger:This is a debug message 3975
# INFO:MyLogger:This is an info message 3975
# WARNING:MyLogger:This is a warning message 3975
# ERROR:MyLogger:This is an error message 3975
# CRITICAL:MyLogger:This is a critical message 3975
# DEBUG:MyLogger:This is a debug message 3976
# INFO:MyLogger:This is an info message 3976
# WARNING:MyLogger:This is a warning message 3976
# ERROR:MyLogger:This is an error message 3976
# CRITICAL:MyLogger:This is a critical message 3976
# DEBUG:MyLogger:This is a debug message 3977
# INFO:MyLogger:This is an info message 3977
# WARNING:MyLogger:This is a warning message 3977
# ERROR:MyLogger:This is an error message 3977
# CRITICAL:MyLogger:This is a critical message 3977
# DEBUG:MyLogger:This is a debug message 3978
# INFO:MyLogger:This is an info message 3978
# WARNING:MyLogger:This is a warning message 3978
# ERROR:MyLogger:This is an error message 3978
# CRITICAL:MyLogger:This is a critical message 3978
# DEBUG:MyLogger:This is a debug message 3979
# INFO:MyLogger:This is an info message 3979
# WARNING:MyLogger:This is a warning message 3979
# ERROR:MyLogger:This is an error message 3979
# CRITICAL:MyLogger:This is a critical message 3979
# DEBUG:MyLogger:This is a debug message 3980
# INFO:MyLogger:This is an info message 3980
# WARNING:MyLogger:This is a warning message 3980
# ERROR:MyLogger:This is an error message 3980
# CRITICAL:MyLogger:This is a critical message 3980
# DEBUG:MyLogger:This is a debug message 3981
# INFO:MyLogger:This is an info message 3981
# WARNING:MyLogger:This is a warning message 3981
# ERROR:MyLogger:This is an error message 3981
# CRITICAL:MyLogger:This is a critical message 3981
# DEBUG:MyLogger:This is a debug message 3982
# INFO:MyLogger:This is an info message 3982
# WARNING:MyLogger:This is a warning message 3982
# ERROR:MyLogger:This is an error message 3982
# CRITICAL:MyLogger:This is a critical message 3982
# DEBUG:MyLogger:This is a debug message 3983
# INFO:MyLogger:This is an info message 3983
# WARNING:MyLogger:This is a warning message 3983
# ERROR:MyLogger:This is an error message 3983
# CRITICAL:MyLogger:This is a critical message 3983
# DEBUG:MyLogger:This is a debug message 3984
# INFO:MyLogger:This is an info message 3984
# WARNING:MyLogger:This is a warning message 3984
# ERROR:MyLogger:This is an error message 3984
# CRITICAL:MyLogger:This is a critical message 3984
# DEBUG:MyLogger:This is a debug message 3985
# INFO:MyLogger:This is an info message 3985
# WARNING:MyLogger:This is a warning message 3985
# ERROR:MyLogger:This is an error message 3985
# CRITICAL:MyLogger:This is a critical message 3985
# DEBUG:MyLogger:This is a debug message 3986
# INFO:MyLogger:This is an info message 3986
# WARNING:MyLogger:This is a warning message 3986
# ERROR:MyLogger:This is an error message 3986
# CRITICAL:MyLogger:This is a critical message 3986
# DEBUG:MyLogger:This is a debug message 3987
# INFO:MyLogger:This is an info message 3987
# WARNING:MyLogger:This is a warning message 3987
# ERROR:MyLogger:This is an error message 3987
# CRITICAL:MyLogger:This is a critical message 3987
# DEBUG:MyLogger:This is a debug message 3988
# INFO:MyLogger:This is an info message 3988
# WARNING:MyLogger:This is a warning message 3988
# ERROR:MyLogger:This is an error message 3988
# CRITICAL:MyLogger:This is a critical message 3988
# DEBUG:MyLogger:This is a debug message 3989
# INFO:MyLogger:This is an info message 3989
# WARNING:MyLogger:This is a warning message 3989
# ERROR:MyLogger:This is an error message 3989
# CRITICAL:MyLogger:This is a critical message 3989
# DEBUG:MyLogger:This is a debug message 3990
# INFO:MyLogger:This is an info message 3990
# WARNING:MyLogger:This is a warning message 3990
# ERROR:MyLogger:This is an error message 3990
# CRITICAL:MyLogger:This is a critical message 3990
# DEBUG:MyLogger:This is a debug message 3991
# INFO:MyLogger:This is an info message 3991
# WARNING:MyLogger:This is a warning message 3991
# ERROR:MyLogger:This is an error message 3991
# CRITICAL:MyLogger:This is a critical message 3991
# DEBUG:MyLogger:This is a debug message 3992
# INFO:MyLogger:This is an info message 3992
# WARNING:MyLogger:This is a warning message 3992
# ERROR:MyLogger:This is an error message 3992
# CRITICAL:MyLogger:This is a critical message 3992
# DEBUG:MyLogger:This is a debug message 3993
# INFO:MyLogger:This is an info message 3993
# WARNING:MyLogger:This is a warning message 3993
# ERROR:MyLogger:This is an error message 3993
# CRITICAL:MyLogger:This is a critical message 3993
# DEBUG:MyLogger:This is a debug message 3994
# INFO:MyLogger:This is an info message 3994
# WARNING:MyLogger:This is a warning message 3994
# ERROR:MyLogger:This is an error message 3994
# CRITICAL:MyLogger:This is a critical message 3994
# DEBUG:MyLogger:This is a debug message 3995
# INFO:MyLogger:This is an info message 3995
# WARNING:MyLogger:This is a warning message 3995
# ERROR:MyLogger:This is an error message 3995
# CRITICAL:MyLogger:This is a critical message 3995
# DEBUG:MyLogger:This is a debug message 3996
# INFO:MyLogger:This is an info message 3996
# WARNING:MyLogger:This is a warning message 3996
# ERROR:MyLogger:This is an error message 3996
# CRITICAL:MyLogger:This is a critical message 3996
# DEBUG:MyLogger:This is a debug message 3997
# INFO:MyLogger:This is an info message 3997
# WARNING:MyLogger:This is a warning message 3997
# ERROR:MyLogger:This is an error message 3997
# CRITICAL:MyLogger:This is a critical message 3997
# DEBUG:MyLogger:This is a debug message 3998
# INFO:MyLogger:This is an info message 3998
# WARNING:MyLogger:This is a warning message 3998
# ERROR:MyLogger:This is an error message 3998
# CRITICAL:MyLogger:This is a critical message 3998
# DEBUG:MyLogger:This is a debug message 3999
# INFO:MyLogger:This is an info message 3999
# WARNING:MyLogger:This is a warning message 3999
# ERROR:MyLogger:This is an error message 3999
# CRITICAL:MyLogger:This is a critical message 3999
# DEBUG:MyLogger:This is a debug message 4000
# INFO:MyLogger:This is an info message 4000
# WARNING:MyLogger:This is a warning message 4000
# ERROR:MyLogger:This is an error message 4000
# CRITICAL:MyLogger:This is a critical message 4000
# DEBUG:MyLogger:This is a debug message 4001
# INFO:MyLogger:This is an info message 4001
# WARNING:MyLogger:This is a warning message 4001
# ERROR:MyLogger:This is an error message 4001
# CRITICAL:MyLogger:This is a critical message 4001
# DEBUG:MyLogger:This is a debug message 4002
# INFO:MyLogger:This is an info message 4002
# WARNING:MyLogger:This is a warning message 4002
# ERROR:MyLogger:This is an error message 4002
# CRITICAL:MyLogger:This is a critical message 4002
# DEBUG:MyLogger:This is a debug message 4003
# INFO:MyLogger:This is an info message 4003
# WARNING:MyLogger:This is a warning message 4003
# ERROR:MyLogger:This is an error message 4003
# CRITICAL:MyLogger:This is a critical message 4003
# DEBUG:MyLogger:This is a debug message 4004
# INFO:MyLogger:This is an info message 4004
# WARNING:MyLogger:This is a warning message 4004
# ERROR:MyLogger:This is an error message 4004
# CRITICAL:MyLogger:This is a critical message 4004
# DEBUG:MyLogger:This is a debug message 4005
# INFO:MyLogger:This is an info message 4005
# WARNING:MyLogger:This is a warning message 4005
# ERROR:MyLogger:This is an error message 4005
# CRITICAL:MyLogger:This is a critical message 4005
# DEBUG:MyLogger:This is a debug message 4006
# INFO:MyLogger:This is an info message 4006
# WARNING:MyLogger:This is a warning message 4006
# ERROR:MyLogger:This is an error message 4006
# CRITICAL:MyLogger:This is a critical message 4006
# DEBUG:MyLogger:This is a debug message 4007
# INFO:MyLogger:This is an info message 4007
# WARNING:MyLogger:This is a warning message 4007
# ERROR:MyLogger:This is an error message 4007
# CRITICAL:MyLogger:This is a critical message 4007
# DEBUG:MyLogger:This is a debug message 4008
# INFO:MyLogger:This is an info message 4008
# WARNING:MyLogger:This is a warning message 4008
# ERROR:MyLogger:This is an error message 4008
# CRITICAL:MyLogger:This is a critical message 4008
# DEBUG:MyLogger:This is a debug message 4009
# INFO:MyLogger:This is an info message 4009
# WARNING:MyLogger:This is a warning message 4009
# ERROR:MyLogger:This is an error message 4009
# CRITICAL:MyLogger:This is a critical message 4009
# DEBUG:MyLogger:This is a debug message 4010
# INFO:MyLogger:This is an info message 4010
# WARNING:MyLogger:This is a warning message 4010
# ERROR:MyLogger:This is an error message 4010
# CRITICAL:MyLogger:This is a critical message 4010
# DEBUG:MyLogger:This is a debug message 4011
# INFO:MyLogger:This is an info message 4011
# WARNING:MyLogger:This is a warning message 4011
# ERROR:MyLogger:This is an error message 4011
# CRITICAL:MyLogger:This is a critical message 4011
# DEBUG:MyLogger:This is a debug message 4012
# INFO:MyLogger:This is an info message 4012
# WARNING:MyLogger:This is a warning message 4012
# ERROR:MyLogger:This is an error message 4012
# CRITICAL:MyLogger:This is a critical message 4012
# DEBUG:MyLogger:This is a debug message 4013
# INFO:MyLogger:This is an info message 4013
# WARNING:MyLogger:This is a warning message 4013
# ERROR:MyLogger:This is an error message 4013
# CRITICAL:MyLogger:This is a critical message 4013
# DEBUG:MyLogger:This is a debug message 4014
# INFO:MyLogger:This is an info message 4014
# WARNING:MyLogger:This is a warning message 4014
# ERROR:MyLogger:This is an error message 4014
# CRITICAL:MyLogger:This is a critical message 4014
# DEBUG:MyLogger:This is a debug message 4015
# INFO:MyLogger:This is an info message 4015
# WARNING:MyLogger:This is a warning message 4015
# ERROR:MyLogger:This is an error message 4015
# CRITICAL:MyLogger:This is a critical message 4015
# DEBUG:MyLogger:This is a debug message 4016
# INFO:MyLogger:This is an info message 4016
# WARNING:MyLogger:This is a warning message 4016
# ERROR:MyLogger:This is an error message 4016
# CRITICAL:MyLogger:This is a critical message 4016
# DEBUG:MyLogger:This is a debug message 4017
# INFO:MyLogger:This is an info message 4017
# WARNING:MyLogger:This is a warning message 4017
# ERROR:MyLogger:This is an error message 4017
# CRITICAL:MyLogger:This is a critical message 4017
# DEBUG:MyLogger:This is a debug message 4018
# INFO:MyLogger:This is an info message 4018
# WARNING:MyLogger:This is a warning message 4018
# ERROR:MyLogger:This is an error message 4018
# CRITICAL:MyLogger:This is a critical message 4018
# DEBUG:MyLogger:This is a debug message 4019
# INFO:MyLogger:This is an info message 4019
# WARNING:MyLogger:This is a warning message 4019
# ERROR:MyLogger:This is an error message 4019
# CRITICAL:MyLogger:This is a critical message 4019
# DEBUG:MyLogger:This is a debug message 4020
# INFO:MyLogger:This is an info message 4020
# WARNING:MyLogger:This is a warning message 4020
# ERROR:MyLogger:This is an error message 4020
# CRITICAL:MyLogger:This is a critical message 4020
# DEBUG:MyLogger:This is a debug message 4021
# INFO:MyLogger:This is an info message 4021
# WARNING:MyLogger:This is a warning message 4021
# ERROR:MyLogger:This is an error message 4021
# CRITICAL:MyLogger:This is a critical message 4021
# DEBUG:MyLogger:This is a debug message 4022
# INFO:MyLogger:This is an info message 4022
# WARNING:MyLogger:This is a warning message 4022
# ERROR:MyLogger:This is an error message 4022
# CRITICAL:MyLogger:This is a critical message 4022
# DEBUG:MyLogger:This is a debug message 4023
# INFO:MyLogger:This is an info message 4023
# WARNING:MyLogger:This is a warning message 4023
# ERROR:MyLogger:This is an error message 4023
# CRITICAL:MyLogger:This is a critical message 4023
# DEBUG:MyLogger:This is a debug message 4024
# INFO:MyLogger:This is an info message 4024
# WARNING:MyLogger:This is a warning message 4024
# ERROR:MyLogger:This is an error message 4024
# CRITICAL:MyLogger:This is a critical message 4024
# DEBUG:MyLogger:This is a debug message 4025
# INFO:MyLogger:This is an info message 4025
# WARNING:MyLogger:This is a warning message 4025
# ERROR:MyLogger:This is an error message 4025
# CRITICAL:MyLogger:This is a critical message 4025
# DEBUG:MyLogger:This is a debug message 4026
# INFO:MyLogger:This is an info message 4026
# WARNING:MyLogger:This is a warning message 4026
# ERROR:MyLogger:This is an error message 4026
# CRITICAL:MyLogger:This is a critical message 4026
# DEBUG:MyLogger:This is a debug message 4027
# INFO:MyLogger:This is an info message 4027
# WARNING:MyLogger:This is a warning message 4027
# ERROR:MyLogger:This is an error message 4027
# CRITICAL:MyLogger:This is a critical message 4027
# DEBUG:MyLogger:This is a debug message 4028
# INFO:MyLogger:This is an info message 4028
# WARNING:MyLogger:This is a warning message 4028
# ERROR:MyLogger:This is an error message 4028
# CRITICAL:MyLogger:This is a critical message 4028
# DEBUG:MyLogger:This is a debug message 4029
# INFO:MyLogger:This is an info message 4029
# WARNING:MyLogger:This is a warning message 4029
# ERROR:MyLogger:This is an error message 4029
# CRITICAL:MyLogger:This is a critical message 4029
# DEBUG:MyLogger:This is a debug message 4030
# INFO:MyLogger:This is an info message 4030
# WARNING:MyLogger:This is a warning message 4030
# ERROR:MyLogger:This is an error message 4030
# CRITICAL:MyLogger:This is a critical message 4030
# DEBUG:MyLogger:This is a debug message 4031
# INFO:MyLogger:This is an info message 4031
# WARNING:MyLogger:This is a warning message 4031
# ERROR:MyLogger:This is an error message 4031
# CRITICAL:MyLogger:This is a critical message 4031
# DEBUG:MyLogger:This is a debug message 4032
# INFO:MyLogger:This is an info message 4032
# WARNING:MyLogger:This is a warning message 4032
# ERROR:MyLogger:This is an error message 4032
# CRITICAL:MyLogger:This is a critical message 4032
# DEBUG:MyLogger:This is a debug message 4033
# INFO:MyLogger:This is an info message 4033
# WARNING:MyLogger:This is a warning message 4033
# ERROR:MyLogger:This is an error message 4033
# CRITICAL:MyLogger:This is a critical message 4033
# DEBUG:MyLogger:This is a debug message 4034
# INFO:MyLogger:This is an info message 4034
# WARNING:MyLogger:This is a warning message 4034
# ERROR:MyLogger:This is an error message 4034
# CRITICAL:MyLogger:This is a critical message 4034
# DEBUG:MyLogger:This is a debug message 4035
# INFO:MyLogger:This is an info message 4035
# WARNING:MyLogger:This is a warning message 4035
# ERROR:MyLogger:This is an error message 4035
# CRITICAL:MyLogger:This is a critical message 4035
# DEBUG:MyLogger:This is a debug message 4036
# INFO:MyLogger:This is an info message 4036
# WARNING:MyLogger:This is a warning message 4036
# ERROR:MyLogger:This is an error message 4036
# CRITICAL:MyLogger:This is a critical message 4036
# DEBUG:MyLogger:This is a debug message 4037
# INFO:MyLogger:This is an info message 4037
# WARNING:MyLogger:This is a warning message 4037
# ERROR:MyLogger:This is an error message 4037
# CRITICAL:MyLogger:This is a critical message 4037
# DEBUG:MyLogger:This is a debug message 4038
# INFO:MyLogger:This is an info message 4038
# WARNING:MyLogger:This is a warning message 4038
# ERROR:MyLogger:This is an error message 4038
# CRITICAL:MyLogger:This is a critical message 4038
# DEBUG:MyLogger:This is a debug message 4039
# INFO:MyLogger:This is an info message 4039
# WARNING:MyLogger:This is a warning message 4039
# ERROR:MyLogger:This is an error message 4039
# CRITICAL:MyLogger:This is a critical message 4039
# DEBUG:MyLogger:This is a debug message 4040
# INFO:MyLogger:This is an info message 4040
# WARNING:MyLogger:This is a warning message 4040
# ERROR:MyLogger:This is an error message 4040
# CRITICAL:MyLogger:This is a critical message 4040
# ...
# DEBUG:MyLogger:This is a debug message 4778
# INFO:MyLogger:This is an info message 4778
# WARNING:MyLogger:This is a warning message 4778
# ERROR:MyLogger:This is an error message 4778
# CRITICAL:MyLogger:This is a critical message 4778
# DEBUG:MyLogger:This is a debug message 4779
# INFO:MyLogger:This is an info message 4779
# WARNING:MyLogger:This is a warning message 4779
# ERROR:MyLogger:This is an error message 4779
# CRITICAL:MyLogger:This is a critical message 4779
# DEBUG:MyLogger:This is a debug message 4780
# INFO:MyLogger:This is an info message 4780
# WARNING:MyLogger:This is a warning message 4780
# ERROR:MyLogger:This is an error message 4780
# CRITICAL:MyLogger:This is a critical message 4780
# DEBUG:MyLogger:This is a debug message 4781
# INFO:MyLogger:This is an info message 4781
# WARNING:MyLogger:This is a warning message 4781
# ERROR:MyLogger:This is an error message 4781
# CRITICAL:MyLogger:This is a critical message 4781
# DEBUG:MyLogger:This is a debug message 4782
# INFO:MyLogger:This is an info message 4782
# WARNING:MyLogger:This is a warning message 4782
# ERROR:MyLogger:This is an error message 4782
# CRITICAL:MyLogger:This is a critical message 4782
# DEBUG:MyLogger:This is a debug message 4783
# INFO:MyLogger:This is an info message 4783
# WARNING:MyLogger:This is a warning message 4783
# ERROR:MyLogger:This is an error message 4783
# CRITICAL:MyLogger:This is a critical message 4783
# DEBUG:MyLogger:This is a debug message 4784
# INFO:MyLogger:This is an info message 4784
# WARNING:MyLogger:This is a warning message 4784
# ERROR:MyLogger:This is an error message 4784
# CRITICAL:MyLogger:This is a critical message 4784
# DEBUG:MyLogger:This is a debug message 4785
# INFO:MyLogger:This is an info message 4785
# WARNING:MyLogger:This is a warning message 4785
# ERROR:MyLogger:This is an error message 4785
# CRITICAL:MyLogger:This is a critical message 4785
# DEBUG:MyLogger:This is a debug message 4786
# INFO:MyLogger:This is an info message 4786
# WARNING:MyLogger:This is a warning message 4786
# ERROR:MyLogger:This is an error message 4786
# CRITICAL:MyLogger:This is a critical message 4786
# DEBUG:MyLogger:This is a debug message 4787
# INFO:MyLogger:This is an info message 4787
# WARNING:MyLogger:This is a warning message 4787
# ERROR:MyLogger:This is an error message 4787
# CRITICAL:MyLogger:This is a critical message 4787
# DEBUG:MyLogger:This is a debug message 4788
# INFO:MyLogger:This is an info message 4788
# WARNING:MyLogger:This is a warning message 4788
# ERROR:MyLogger:This is an error message 4788
# CRITICAL:MyLogger:This is a critical message 4788
# DEBUG:MyLogger:This is a debug message 4789
# INFO:MyLogger:This is an info message 4789
# WARNING:MyLogger:This is a warning message 4789
# ERROR:MyLogger:This is an error message 4789
# CRITICAL:MyLogger:This is a critical message 4789
# DEBUG:MyLogger:This is a debug message 4790
# INFO:MyLogger:This is an info message 4790
# WARNING:MyLogger:This is a warning message 4790
# ERROR:MyLogger:This is an error message 4790
# CRITICAL:MyLogger:This is a critical message 4790
# DEBUG:MyLogger:This is a debug message 4791
# INFO:MyLogger:This is an info message 4791
# WARNING:MyLogger:This is a warning message 4791
# ERROR:MyLogger:This is an error message 4791
# CRITICAL:MyLogger:This is a critical message 4791
# DEBUG:MyLogger:This is a debug message 4792
# INFO:MyLogger:This is an info message 4792
# WARNING:MyLogger:This is a warning message 4792
# ERROR:MyLogger:This is an error message 4792
# CRITICAL:MyLogger:This is a critical message 4792
# DEBUG:MyLogger:This is a debug message 4793
# INFO:MyLogger:This is an info message 4793
# WARNING:MyLogger:This is a warning message 4793
# ERROR:MyLogger:This is an error message 4793
# CRITICAL:MyLogger:This is a critical message 4793
# DEBUG:MyLogger:This is a debug message 4794
# INFO:MyLogger:This is an info message 4794
# WARNING:MyLogger:This is a warning message 4794
# ERROR:MyLogger:This is an error message 4794
# CRITICAL:MyLogger:This is a critical message 4794
# DEBUG:MyLogger:This is a debug message 4795
# INFO:MyLogger:This is an info message 4795
# WARNING:MyLogger:This is a warning message 4795
# ERROR:MyLogger:This is an error message 4795
# CRITICAL:MyLogger:This is a critical message 4795
# DEBUG:MyLogger:This is a debug message 4796
# INFO:MyLogger:This is an info message 4796
# WARNING:MyLogger:This is a warning message 4796
# ERROR:MyLogger:This is an error message 4796
# CRITICAL:MyLogger:This is a critical message 4796
# DEBUG:MyLogger:This is a debug message 4797
# INFO:MyLogger:This is an info message 4797
# WARNING:MyLogger:This is a warning message 4797
# ERROR:MyLogger:This is an error message 4797
# CRITICAL:MyLogger:This is a critical message 4797
# DEBUG:MyLogger:This is a debug message 4798
# INFO:MyLogger:This is an info message 4798
# WARNING:MyLogger:This is a warning message 4798
# ERROR:MyLogger:This is an error message 4798
# CRITICAL:MyLogger:This is a critical message 4798
# DEBUG:MyLogger:This is a debug message 4799
# INFO:MyLogger:This is an info message 4799
# WARNING:MyLogger:This is a warning message 4799
# ERROR:MyLogger:This is an error message 4799
# CRITICAL:MyLogger:This is a critical message 4799
# DEBUG:MyLogger:This is a debug message 4800
# INFO:MyLogger:This is an info message 4800
# WARNING:MyLogger:This is a warning message 4800
# ERROR:MyLogger:This is an error message 4800
# CRITICAL:MyLogger:This is a critical message 4800
# DEBUG:MyLogger:This is a debug message 4801
# INFO:MyLogger:This is an info message 4801
# WARNING:MyLogger:This is a warning message 4801
# ERROR:MyLogger:This is an error message 4801
# CRITICAL:MyLogger:This is a critical message 4801
# DEBUG:MyLogger:This is a debug message 4802
# INFO:MyLogger:This is an info message 4802
# WARNING:MyLogger:This is a warning message 4802
# ERROR:MyLogger:This is an error message 4802
# CRITICAL:MyLogger:This is a critical message 4802
# DEBUG:MyLogger:This is a debug message 4803
# INFO:MyLogger:This is an info message 4803
# WARNING:MyLogger:This is a warning message 4803
# ERROR:MyLogger:This is an error message 4803
# CRITICAL:MyLogger:This is a critical message 4803
# DEBUG:MyLogger:This is a debug message 4804
# INFO:MyLogger:This is an info message 4804
# WARNING:MyLogger:This is a warning message 4804
# ERROR:MyLogger:This is an error message 4804
# CRITICAL:MyLogger:This is a critical message 4804
# DEBUG:MyLogger:This is a debug message 4805
# INFO:MyLogger:This is an info message 4805
# WARNING:MyLogger:This is a warning message 4805
# ERROR:MyLogger:This is an error message 4805
# CRITICAL:MyLogger:This is a critical message 4805
# DEBUG:MyLogger:This is a debug message 4806
# INFO:MyLogger:This is an info message 4806
# WARNING:MyLogger:This is a warning message 4806
# ERROR:MyLogger:This is an error message 4806
# CRITICAL:MyLogger:This is a critical message 4806
# DEBUG:MyLogger:This is a debug message 4807
# INFO:MyLogger:This is an info message 4807
# WARNING:MyLogger:This is a warning message 4807
# ERROR:MyLogger:This is an error message 4807
# CRITICAL:MyLogger:This is a critical message 4807
# DEBUG:MyLogger:This is a debug message 4808
# INFO:MyLogger:This is an info message 4808
# WARNING:MyLogger:This is a warning message 4808
# ERROR:MyLogger:This is an error message 4808
# CRITICAL:MyLogger:This is a critical message 4808
# DEBUG:MyLogger:This is a debug message 4809
# INFO:MyLogger:This is an info message 4809
# WARNING:MyLogger:This is a warning message 4809
# ERROR:MyLogger:This is an error message 4809
# CRITICAL:MyLogger:This is a critical message 4809
# DEBUG:MyLogger:This is a debug message 4810
# INFO:MyLogger:This is an info message 4810
# WARNING:MyLogger:This is a warning message 4810
# ERROR:MyLogger:This is an error message 4810
# CRITICAL:MyLogger:This is a critical message 4810
# DEBUG:MyLogger:This is a debug message 4811
# INFO:MyLogger:This is an info message 4811
# WARNING:MyLogger:This is a warning message 4811
# ERROR:MyLogger:This is an error message 4811
# CRITICAL:MyLogger:This is a critical message 4811
# DEBUG:MyLogger:This is a debug message 4812
# INFO:MyLogger:This is an info message 4812
# WARNING:MyLogger:This is a warning message 4812
# ERROR:MyLogger:This is an error message 4812
# CRITICAL:MyLogger:This is a critical message 4812
# DEBUG:MyLogger:This is a debug message 4813
# INFO:MyLogger:This is an info message 4813
# WARNING:MyLogger:This is a warning message 4813
# ERROR:MyLogger:This is an error message 4813
# CRITICAL:MyLogger:This is a critical message 4813
# DEBUG:MyLogger:This is a debug message 4814
# INFO:MyLogger:This is an info message 4814
# WARNING:MyLogger:This is a warning message 4814
# ERROR:MyLogger:This is an error message 4814
# CRITICAL:MyLogger:This is a critical message 4814
# DEBUG:MyLogger:This is a debug message 4815
# INFO:MyLogger:This is an info message 4815
# WARNING:MyLogger:This is a warning message 4815
# ERROR:MyLogger:This is an error message 4815
# CRITICAL:MyLogger:This is a critical message 4815
# DEBUG:MyLogger:This is a debug message 4816
# INFO:MyLogger:This is an info message 4816
# WARNING:MyLogger:This is a warning message 4816
# ERROR:MyLogger:This is an error message 4816
# CRITICAL:MyLogger:This is a critical message 4816
# DEBUG:MyLogger:This is a debug message 4817
# INFO:MyLogger:This is an info message 4817
# WARNING:MyLogger:This is a warning message 4817
# ERROR:MyLogger:This is an error message 4817
# CRITICAL:MyLogger:This is a critical message 4817
# DEBUG:MyLogger:This is a debug message 4818
# INFO:MyLogger:This is an info message 4818
# WARNING:MyLogger:This is a warning message 4818
# ERROR:MyLogger:This is an error message 4818
# CRITICAL:MyLogger:This is a critical message 4818
# DEBUG:MyLogger:This is a debug message 4819
# INFO:MyLogger:This is an info message 4819
# WARNING:MyLogger:This is a warning message 4819
# ERROR:MyLogger:This is an error message 4819
# CRITICAL:MyLogger:This is a critical message 4819
# DEBUG:MyLogger:This is a debug message 4820
# INFO:MyLogger:This is an info message 4820
# WARNING:MyLogger:This is a warning message 4820
# ERROR:MyLogger:This is an error message 4820
# CRITICAL:MyLogger:This is a critical message 4820
# DEBUG:MyLogger:This is a debug message 4821
# INFO:MyLogger:This is an info message 4821
# WARNING:MyLogger:This is a warning message 4821
# ERROR:MyLogger:This is an error message 4821
# CRITICAL:MyLogger:This is a critical message 4821
# DEBUG:MyLogger:This is a debug message 4822
# INFO:MyLogger:This is an info message 4822
# WARNING:MyLogger:This is a warning message 4822
# ERROR:MyLogger:This is an error message 4822
# CRITICAL:MyLogger:This is a critical message 4822
# DEBUG:MyLogger:This is a debug message 4823
# INFO:MyLogger:This is an info message 4823
# WARNING:MyLogger:This is a warning message 4823
# ERROR:MyLogger:This is an error message 4823
# CRITICAL:MyLogger:This is a critical message 4823
# DEBUG:MyLogger:This is a debug message 4824
# INFO:MyLogger:This is an info message 4824
# WARNING:MyLogger:This is a warning message 4824
# ERROR:MyLogger:This is an error message 4824
# CRITICAL:MyLogger:This is a critical message 4824
# DEBUG:MyLogger:This is a debug message 4825
# INFO:MyLogger:This is an info message 4825
# WARNING:MyLogger:This is a warning message 4825
# ERROR:MyLogger:This is an error message 4825
# CRITICAL:MyLogger:This is a critical message 4825
# DEBUG:MyLogger:This is a debug message 4826
# INFO:MyLogger:This is an info message 4826
# WARNING:MyLogger:This is a warning message 4826
# ERROR:MyLogger:This is an error message 4826
# CRITICAL:MyLogger:This is a critical message 4826
# DEBUG:MyLogger:This is a debug message 4827
# INFO:MyLogger:This is an info message 4827
# WARNING:MyLogger:This is a warning message 4827
# ERROR:MyLogger:This is an error message 4827
# CRITICAL:MyLogger:This is a critical message 4827
# DEBUG:MyLogger:This is a debug message 4828
# INFO:MyLogger:This is an info message 4828
# WARNING:MyLogger:This is a warning message 4828
# ERROR:MyLogger:This is an error message 4828
# CRITICAL:MyLogger:This is a critical message 4828
# DEBUG:MyLogger:This is a debug message 4829
# INFO:MyLogger:This is an info message 4829
# WARNING:MyLogger:This is a warning message 4829
# ERROR:MyLogger:This is an error message 4829
# CRITICAL:MyLogger:This is a critical message 4829
# DEBUG:MyLogger:This is a debug message 4830
# INFO:MyLogger:This is an info message 4830
# WARNING:MyLogger:This is a warning message 4830
# ERROR:MyLogger:This is an error message 4830
# CRITICAL:MyLogger:This is a critical message 4830
# DEBUG:MyLogger:This is a debug message 4831
# INFO:MyLogger:This is an info message 4831
# WARNING:MyLogger:This is a warning message 4831
# ERROR:MyLogger:This is an error message 4831
# CRITICAL:MyLogger:This is a critical message 4831
# DEBUG:MyLogger:This is a debug message 4832
# INFO:MyLogger:This is an info message 4832
# WARNING:MyLogger:This is a warning message 4832
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-29a72e8141f9> in <cell line: 0>()
#      28         logger.debug(f'This is a debug message {i}')
#      29         logger.info(f'This is an info message {i}')
# ---> 30         logger.warning(f'This is a warning message {i}')
#      31         logger.error(f'This is an error message {i}')
#      32         logger.critical(f'This is a critical message {i}')
#
# /usr/lib/python3.11/logging/__init__.py in warning(self, msg, *args, **kwargs)
#    1499         """
#    1500         if self.isEnabledFor(WARNING):
# -> 1501             self._log(WARNING, msg, args, **kwargs)
#    1502
#    1503     def warn(self, msg, *args, **kwargs):
#
# /usr/lib/python3.11/logging/__init__.py in _log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1632         record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1633                                  exc_info, func, extra, sinfo)
# -> 1634         self.handle(record)
#    1635
#    1636     def handle(self, record):
#
# /usr/lib/python3.11/logging/__init__.py in handle(self, record)
#    1642         """
#    1643         if (not self.disabled) and self.filter(record):
# -> 1644             self.callHandlers(record)
#    1645
#    1646     def addHandler(self, hdlr):
#
# /usr/lib/python3.11/logging/__init__.py in callHandlers(self, record)
#    1704                 found = found + 1
#    1705                 if record.levelno >= hdlr.level:
# -> 1706                     hdlr.handle(record)
#    1707             if not c.propagate:
#    1708                 c = None    #break out
#
# /usr/lib/python3.11/logging/__init__.py in handle(self, record)
#     976             self.acquire()
#     977             try:
# --> 978                 self.emit(record)
#     979             finally:
#     980                 self.release()
#
# /usr/lib/python3.11/logging/__init__.py in emit(self, record)
#    1112             # issue 35046: merged two stream.writes into one.
#    1113             stream.write(msg + self.terminator)
# -> 1114             self.flush()
#    1115         except RecursionError:  # See issue 36272
#    1116             raise
#
# /usr/lib/python3.11/logging/__init__.py in flush(self)
#    1092         try:
#    1093             if self.stream and hasattr(self.stream, "flush"):
# -> 1094                 self.stream.flush()
#    1095         finally:
#    1096             self.release()
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in flush(self)
#     348                 self.pub_thread.schedule(evt.set)
#     349                 # and give a timeout to avoid
# --> 350                 if not evt.wait(self.flush_timeout):
#     351                     # write directly to __stderr__ instead of warning because
#     352                     # if this is happening sys.stderr may be the problem.
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     627             signaled = self._flag
#     628             if not signaled:
# --> 629                 signaled = self._cond.wait(timeout)
#     630             return signaled
#     631
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     329             else:
#     330                 if timeout > 0:
# --> 331                     gotit = waiter.acquire(True, timeout)
#     332                 else:
#     333                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
